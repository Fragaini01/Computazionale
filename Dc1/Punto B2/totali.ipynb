# %%
import snscrape
import snscrape.modules.twitter as sn
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
dati = pd.read_csv('/home/francesco/Codici/Computazionale/Dc1/Punto B2/Gas_Serra_Tot.csv' , index_col = 0)
dati['Data'] = pd.to_datetime(dati.Data)
dati['Anno'] = dati.Data.dt.year

# %%
bar = dati.groupby(['Anno']).Data.count()

bar.plot.bar(label = 'Gas serra in italia con almeno 10 like')
plt.legend()
