# %%
import pandas as pd
import numpy as np
from scipy import stats as st
from matplotlib import pyplot as plt

# %%
#Lettura dataset
LR = pd.read_csv('/home/francesco/Codici/Computazionale/Dc1/Punto A/LisiekiRaymoHansen.csv' , header = 2 , sep = '\t')
ZH = pd.read_csv('/home/francesco/Codici/Computazionale/Dc1/Punto A/ZachosHansen.csv' , header = 2 , sep = '\t')
FH = pd.read_csv('/home/francesco/Codici/Computazionale/Dc1/Punto A/FriedrichHansen.csv' , header = 2 , sep = '\t')
Noaa = pd.read_csv('/home/francesco/Codici/Computazionale/Dc1/Punto A/NOAA.csv' , header = 3 , sep = '\t')

# %%
plt.plot(LR['YB 2015'] , LR['Anomaly(°C)'] , label = 'LR')
plt.plot(ZH['YB 2015'] , ZH['Anomaly(°C)'] , label = 'ZH')
plt.plot(FH['YB 2015'] , FH['Anomaly(°C)'] , label = 'FH')
plt.plot(Noaa['YB 2015'] , Noaa['Anomaly(°C)'] , label = 'Noaa')
plt.xlim(0,4e5 )
plt.axvline(x = 200000 , label = 'Comparsa uomo')
plt.legend()

# %%
plt.plot(LR['YB 2015'] , LR['Anomaly(°C)'] , label = 'LR')
plt.plot(ZH['YB 2015'] , ZH['Anomaly(°C)'] , label = 'ZH')
plt.plot(FH['YB 2015'] , FH['Anomaly(°C)'] , label = 'FH')
plt.plot(Noaa['YB 2015'] , Noaa['Anomaly(°C)'] , label = 'Noaa')
plt.xlim(0,10000)
plt.legend()
